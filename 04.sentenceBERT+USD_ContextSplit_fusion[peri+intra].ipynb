# %%
import numpy as np, pandas as pd, torch, os, glob
import pickle
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold

os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %%
#pickle loading
# merge experiment
PeriHD_USD_data_train_pkl = glob.glob("./dataset/PeriHD_pickle_save/USD_sample2693_only-merge-sequence_contextsplit-pos_neg/train/*_fixed_re-marked_merge.pkl")
PeriHD_USD_data_valid_pkl = glob.glob("./dataset/PeriHD_pickle_save/USD_sample2693_only-merge-sequence_contextsplit-pos_neg/valid/*_fixed_re-marked_merge.pkl")
IntraHD_USD_data_train_pkl = glob.glob("./dataset/IntraHD_pickle_save/USD_sample1124_sequence_fullcontext/train/*_fixed_re-marked_merge.pkl")
IntraHD_USD_data_valid_pkl = glob.glob("./dataset/IntraHD_pickle_save/USD_sample1124_sequence_fullcontext/valid/*_fixed_re-marked_merge.pkl")

# %%
def pk2pf(pkl_list):
    data_train = []
    for pk in pkl_list:
        with open(pk, 'rb') as f:
            pk_dict = pickle.load(f)
        data_train.append(pk_dict)
    data_train = pd.DataFrame(data_train)
    
    return data_train
PeriHD_USD_data_train = pk2pf(PeriHD_USD_data_train_pkl)
PeriHD_USD_data_valid = pk2pf(PeriHD_USD_data_valid_pkl)
IntraHD_USD_data_train = pk2pf(IntraHD_USD_data_train_pkl)
IntraHD_USD_data_valid = pk2pf(IntraHD_USD_data_valid_pkl)
PeriHD_USD_data_train['datatype']='PeriHD'
PeriHD_USD_data_valid['datatype']='PeriHD'
IntraHD_USD_data_train['datatype']='IntraHD'
IntraHD_USD_data_valid['datatype']='IntraHD'
USD_data_train = pd.concat([PeriHD_USD_data_train, IntraHD_USD_data_train])
USD_data_valid = pd.concat([PeriHD_USD_data_valid, IntraHD_USD_data_valid])

# %%
print(len(USD_data_train.label.values)-sum(USD_data_train.label.values), sum(USD_data_train.label.values))
print(len(USD_data_valid.label.values)-sum(USD_data_valid.label.values), sum(USD_data_valid.label.values))
# Out:
# 11514 1529
# 1439 227

# %%
# ### USD model embedding
USD_training_embeddings = np.array(USD_data_train.embed.tolist())
USD_validation_embeddings = np.array(USD_data_valid.embed.tolist())
print("Internal train", USD_training_embeddings.shape)
print("Internal test" ,USD_validation_embeddings.shape)
# Out:
# Internal train (13043, 512)
# Internal test (1666, 512)

# %%
import keras
def create_model(input_shape = (512,)):
  model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape = input_shape),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation='sigmoid')
  ])
  # model.compile(loss=FocalTverskyLoss, 
  #             optimizer='adam',
  #             metrics=['acc'])
  model.compile(loss='binary_crossentropy', 
              optimizer='adam',
              metrics=['acc'])
  return model
# Out:
# 2023-04-07 10:27:40.198536: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 10:27:40.411466: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-07 10:27:41.115182: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-07 10:27:41.115261: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-07 10:27:41.115268: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, roc_curve, precision_recall_curve, roc_auc_score
from sklearn.metrics import confusion_matrix
import matplotlib.pylab as plt
def get_weight_path(fold, train_type):
    return "./model_weight/PeriHD_and_IntraHD/weights_periHD_KFold={}[{}-only-merge-sequnece-resplit-periHD-neg+pos].h5".format(fold,train_type)
# return "./model_weight/PeriHD_and_IntraHD/weights_periHD_KFold={}[{}-only-merge-sequnece-resplit].h5".format(fold,train_type)
    # return "./model_weight/PeriHD/weights_periHD_KFold={}[{}-only-merge-sequnece-resplit].h5".format(fold,train_type)
    
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
history_stack = []
# fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(19,5))
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
CM_train = []
CM_test = []
eval = False
train_type = 'USD'
fold_no = 1
if train_type=="USD":
    in_shape = 512
    training_embedding_ = USD_training_embeddings
    validation_embedding = USD_validation_embeddings
    data_train = USD_data_train
    data_valid = USD_data_valid

train_binary_pred_and_score = []
test_binary_pred_and_score = [ ]
for train, test in kfold.split(training_embedding_, data_train['label'].values.tolist()):
    weight_name = get_weight_path(fold_no, train_type)
    cls_model = create_model(input_shape=(in_shape,))
    if eval==False:
        callbacks = [
            EarlyStopping(     #EarlyStopping is used to stop at the epoch where val_accuracy does not improve significantly
                monitor='val_loss',
                min_delta=1e-4,
                patience=10,
                verbose=0
            ),
            ModelCheckpoint(
                filepath=weight_name,
                monitor='val_loss', 
                mode='min', 
                save_best_only=True,
                save_weights_only=True,
                verbose=0
            )
        ]
        history = cls_model.fit(training_embedding_[train], 
                data_train['label'].values[train], 
                batch_size=64, 
                validation_data=(training_embedding_[test], data_train['label'].values[test]), 
                epochs=300, 
                callbacks=callbacks,verbose=0)
        history_stack.append(history)

    elif eval==True:
        cls_model.load_weights(weight_name)
    train_pred = cls_model.predict(training_embedding_)
    test_pred = cls_model.predict(validation_embedding)
    # binary_pred = np.argmax(pred, axis=1)
    train_binary_pred = (train_pred>0.5).astype(np.int8)
    test_binary_pred = (test_pred>0.5).astype(np.int8)
    train_binary_pred_and_score.append([train_pred, train_binary_pred])
    test_binary_pred_and_score.append([test_pred, test_binary_pred])
    
    tn, fp, fn, tp = confusion_matrix(data_train['label'].values, train_binary_pred).ravel()
    # CM_train.append([tn, fp, fn, tp])
    CM_train.append([data_train['label'].values, train_binary_pred])
    tn, fp, fn, tp = confusion_matrix(data_valid['label'].values, test_binary_pred).ravel()
    # CM_test.append([tn, fp, fn, tp])
    CM_test.append([data_valid['label'].values, test_binary_pred])
    
    fpr, tpr, thresholds = roc_curve(data_train['label'].values, train_pred, pos_label=1)
    auc = roc_auc_score(data_train['label'].values, train_pred)
    axs[0].plot(fpr, tpr, label = "Train Fold-{} AUC: {}".format(fold_no, round(auc, 4)))

    fpr, tpr, thresholds = roc_curve(data_valid['label'].values, test_pred, pos_label=1)
    auc = roc_auc_score(data_valid['label'].values, test_pred)
    axs[1].plot(fpr, tpr, label = "Test  Fold-{} AUC: {}".format(fold_no, round(auc, 4)))
    fold_no=fold_no+1

axs[0].plot([0,1],[0,1], linestyle='--')
axs[1].plot([0,1],[0,1], linestyle='--')

axs[0].legend()
axs[0].set_xlabel("FPR")
axs[0].set_ylabel("TPR")
axs[0].set_title(f"[Internal][{train_type}]PeriHD Train ROC-Curve")
axs[1].legend()
axs[1].set_xlabel("FPR")
axs[1].set_ylabel("TPR")
axs[1].set_title(f"[Internal][{train_type}]PeriHD Test ROC-Curve")
# Out:
# 2023-04-07 10:28:19.948292: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-07 10:28:21.753832: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21894 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:22:00.0, compute capability: 8.6
# 2023-04-07 10:28:23.786733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-07 10:28:23.791169: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f0b9e2fa0c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-07 10:28:23.791193: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-04-07 10:28:23.795831: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-07 10:28:23.869198: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-04-07 10:28:23.941948: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 408/408 [==============================] - 1s 2ms/step
# 53/53 [==============================] - 0s 2ms/step
# 408/408 [==============================] - 0s 924us/step
# 53/53 [==============================] - 0s 872us/step
# 408/408 [==============================] - 0s 893us/step
# 53/53 [==============================] - 0s 996us/step
# 408/408 [==============================] - 0s 939us/step
# 53/53 [==============================] - 0s 898us/step
# 408/408 [==============================] - 0s 938us/step
# 53/53 [==============================] - 0s 958us/step
# Text(0.5, 1.0, '[Internal][USD]PeriHD Test ROC-Curve')

# %%
# history_stack[0].history

# %%
from sklearn.metrics import precision_score, f1_score, recall_score, accuracy_score
from sklearn.metrics import classification_report
# 已標記資料效能評估
def metric_calc(array_):
    y_test, y_pred = array_
    report = classification_report(y_test, y_pred, output_dict=True)
    # macro_f1 = report['macro avg']['f1-score']
    # weighted_f1 = report['weighted avg']['f1-score']
    # macro_precision = report['macro avg']['precision']
    # weighted_precision = report['weighted avg']['precision']
    # macro_recall = report['macro avg']['recall']
    # weighted_recall = report['weighted avg']['recall']
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='macro')
    sens = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    spec = tn/(tn+fp)
    return acc, prec, sens, spec, f1

def get_metric(arr):
    mean_arr = np.mean(np.array(arr), axis=0)
    std_arr = np.std(np.array(arr), axis=0)
    return mean_arr, std_arr

# %%
# CM_train = np.array(CM_train)
# CM_test = np.array(CM_test)
T_stack, t_stack = [],[]
for T_ in CM_train:
    T_stack.append(metric_calc(T_))
    
for t_ in CM_test:
    t_stack.append(metric_calc(t_))
#內部資料 - Train & Test
mark_train_mean, mark_train_std = get_metric(T_stack)
mark_test_mean, mark_test_std = get_metric(t_stack)
mark_train = pd.DataFrame(['Accuracy','Precision [macro]', 'Sensitivity [macro]', 'Specificity', 'F1-score [macro]'], columns=[f'{train_type} Metric Train'])
for T_, f in zip(T_stack,['fold-1','fold-2','fold-3','fold-4','fold-5']):mark_train[f] = np.round(T_,4)
mark_train['Mean'] = np.round(mark_train_mean,4)
mark_train['Std'] = np.round(mark_train_std,4)

mark_test = pd.DataFrame(['Accuracy','Precision [macro]', 'Sensitivity [macro]', 'Specificity', 'F1-score [macro]'], columns=[f'{train_type} Metric Test'])
for t_, f in zip(t_stack,['fold-1','fold-2','fold-3','fold-4','fold-5']):mark_test[f] = np.round(t_,4)
mark_test['Mean'] = np.round(mark_test_mean,4)
mark_test['Std'] = np.round(mark_test_std,4)

# %%
temp = {'Train&Valid斷句': [],'真實答案': [],'預測答案': [],'預測分數': []}
for fold_result in train_binary_pred_and_score:
    train_pred_singel = fold_result[0].flatten()
    train_binary_pred_singel = np.round(fold_result[1].flatten(),3).astype(np.float16)
    for i in zip(USD_data_train['text'].tolist(), USD_data_train['label'].tolist(),train_binary_pred_singel, train_pred_singel):
        if i[1]!=i[2]:
            temp['Train&Valid斷句'].append(i[0])
            temp['真實答案'].append(i[1])
            temp['預測答案'].append(i[2])
            temp['預測分數'].append(i[3])

for fold_result in test_binary_pred_and_score:
    test_pred_singel = fold_result[0].flatten()
    test_binary_pred_singel = np.round(fold_result[1].flatten(),3).astype(np.float16)
    for i in zip(USD_data_train['text'].tolist(), USD_data_train['label'].tolist(),test_binary_pred_singel, test_pred_singel):
        if i[1]!=i[2]:
            temp['Train&Valid斷句'].append(i[0])
            temp['真實答案'].append(i[1])
            temp['預測答案'].append(i[2])
            temp['預測分數'].append(i[3])

failed_pf = pd.DataFrame(temp, columns=['Train&Valid斷句','真實答案','預測答案','預測分數'])

# %%
# pd.set_option('display.max_rows', 1000)
# pd.set_option('display.max_columns', 20)
# failed_pf = failed_pf.drop_duplicates(subset='Train&Valid斷句')
# failed_pf.to_csv("./total_fold_faild_predict.csv", index=False, encoding='utf-8-sig')

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 20)
temp = {'斷句': [],'真實答案': [],'預測答案': [],'預測分數': [], '資料型態': []}
for i in zip(USD_data_train['text'].tolist(), USD_data_train['label'].tolist(),train_binary_pred.flatten(), train_pred.flatten(), USD_data_train.datatype):
    if i[1]!=i[2]:
        temp['斷句'].append(i[0])
        temp['真實答案'].append(i[1])
        temp['預測答案'].append(i[2])
        temp['預測分數'].append(np.round(i[3],3))
        temp['資料型態'].append(i[4])
train_failed_pf = pd.DataFrame(temp, columns=['斷句','真實答案','預測答案','預測分數', '資料型態'])

# %%
train_failed_pf
# Out:
#                                                    斷句  真實答案  預測答案   預測分數  \
# 0                     at 1500 BP 88/43mmHg，N/S 200ML      0     1  0.871
# 1                                並主訴雙下肢痠痛不適，至1123結束透析     0     1  0.865
# 2                    Blood flow 200ml/min，by BP調動透析設定     1     0  0.335
# 3                         give ending，趕血後BP150/68mmhg     1     0  0.001
# 4                                予on EKG，潘思宇醫師知現收針外循中     1     0  0.208
# 5   Fe-Back 40mg iv at15:24~16:24止血後訴抽筋改善，透析後防跌評估篩檢0分     0     1  0.801
# 6                                調整UF rate，至13：15結束透析     0     1  0.999
# 7                             補N/S 500 CC， 通知Dr楊聯絡cvs     1     0  0.313
# 8                               BP137/83mmHg，心跳111次/分     1     0  0.483
# 9   BHD BW：82.5kg，透析中血壓介於67-154/35-53mmHg (視血壓情形調整...     1     0  0.343
# 10                   白玫芬醫師囑輸PRBC1u，至15：20因血壓70/45mmHg     1     0  0.265
# 11                          AK clot at 1645，Dr.蔡囑結束透析     1     0  0.030
# 12             血液流速維持200ml/min，2140因血壓54/31mmHg提早結束透析     1     0  0.057
# 13  Duration: 6 hours 透析中血液流速維持200 ml/min，Levophed...     1     0  0.038
# 14                  告知透析前低血壓有吃升壓藥4顆後血壓有慢慢回升，今體重到輕故不脫水     0     1  0.655
# 15                           告知醫師吳泓彥，  囑On N/C 3L/min     1     0  0.127
# 16           今預透析4小時、脫水0-1公斤，透析中18:00 Con''''s change     1     0  0.014
# 17                 於1000依醫囑給予Recormon 2000u iv，病人主訴不適     1     0  0.005
# 18         血液流速維持200ml/min(透析中視血壓情形調整脫水速率)，至20：20結束透析     0     1  0.522
# 19                        at20:15家屬表示病人不舒服，要求提早10分鐘收針     1     0  0.134
# 20                            AVF thrill(++)，不適緩解自行返家     1     0  0.373
# 21                                HD2小時，告知ICU 醫師表結束透析     1     0  0.047
# 22          透析中on BP Monitor監測，血壓維持在110-140/70-80mmHg     1     0  0.005
# 23                           A.V端反抽順暢，於13：00開始進行SLEDD     0     1  0.554
# 24       at 1120電聯蔡醫師表予收針 至11：20結束透析，今共脫水 0.6 L(沖0.3)     1     0  0.155
# 25                             SPO2:94%，  18:00透析中SOB     1     0  0.199
# 26                          趕血後BP150/68mmhg，HD ending     1     0  0.005
# 27             by Dr楊正雯order予提早30分鐘結束透析，左手AVF血管穿刺處已止血     1     0  0.229
# 28  Carnitine 1amp iv at 12:02，病人坐起12:08後有嘔吐出約50CC...     1     0  0.024
# 29               至16：20病人表示全身不適躺不住，血壓:156/100    mmHg     1     0  0.177
# 30                              故直接將血趕回，予帶O2 mask use     1     0  0.135
# 31  血液流速維持200ml/min，at21:00心跳125-130次/分鐘、血壓:128/50...     1     0  0.274
# 32                          Perm-cath fix，AVF thrill+     0     1  0.680
# 33  透析中血壓維持在108-160/56-60 mmHg，AT20:00 病人打哈欠BP:108...     1     0  0.116
# 34                                       煩躁不安，hold HD     1     0  0.445
# 35                        血液流速維持200ml/min，透析中有頭暈及腰痠背痛     1     0  0.021
# 36                   透析後AVF已止血紗布覆蓋，血壓84/60mmHg自服2顆升壓藥     1     0  0.004
# 37                                    give 拔針，休息20min     1     0  0.064
# 38                         透析中病人覺得寒顫腳痠痛不適無法忍耐，體溫36.9度     0     1  0.650
# 39                 1105補300ML N/S並暫停透析20分鐘，至12：05結束透析     1     0  0.327
# 40                        血壓:156/100    mmHg，心跳125次/分     1     0  0.070
# 41                        Dr.潘思宇表示明天暫不考慮安排洗腎，預計會先引流腹水     0     1  0.619
# 42                                    調整UF:0.2，徐凱翔醫師知     0     1  0.726
# 43                     recheck NBP178/98mmHg， HR95次/分     0     1  0.875
# 44                         醫師蔡萬全知，予以N/S 500ML IVD USE     1     0  0.015
# 45   UF 1-2 kg by BP ，at 1010  BP 106/37mmHg con''...     1     0  0.003
# 46              致電於邱彥霖醫師告知現脫水2.0L以及仍有一小時未洗，邱彥霖醫師表示可收針     1     0  0.268
# 47                          透析後血壓：115/64mmHg，心律136次/分     0     1  0.597
# 48                 Levophed16mg調回2ml/hr，右手AVF血管穿刺處已止血     1     0  0.124
# 49                    不適情形BED REST 至18:10，由外傭協助下坐輪椅返家     1     0  0.180
# 50                        give HD ending，f/u HR:76BPM     0     1  0.966
# 51                血壓維持100-130/50-60mmHg左右，流速220ml/min     0     1  0.507
# 52                  血液流速維持200ml/min，於20:18病人表示胸悶一陣一陣的     1     0  0.121
# 53                         GCS：E2NM5V2，透析前量體重後有嘔吐胃消化液     0     1  0.923
# 54                           透析中表頭痛，故要求提早30min HD END     0     1  0.610
# 55         N/C 3L/MIN SPO2：99%，測量血壓158/74mmHg、心跳76Bpm     0     1  0.603
# 56                          10，30護理師及家屬陪同推床離開HDR至急診就醫     1     0  0.112
# 57  HD END，主訴胸悶不適予病人O2 N/C3L/min及on EKG monitor HR...     0     1  0.563
# 58                        血壓仍66-88/44-49mmHg，先將血液趕回體內     1     0  0.039
# 59             協助N/C 3L/MIN 及EKG MONITOR USE，SPO2:98%     1     0  0.002
# 60                     看護協助按摩，血壓:153/87mmHg、心跳:108bpm     1     0  0.017
# 61                      血液流速維持200-220ml/min，透析過程中躁動不安     1     0  0.279
# 62  透析中血壓下降血趕回後血壓回升181/57mmHg，右側perm cath on hepar...     1     0  0.007
# 63                依「血液透析病人透析後防跌評估表」進行防跌篩檢1項，病人持續有嘔吐情形     1     0  0.149
# 64                                        HD畢，病人有抽筋情形     1     0  0.469
# 65                                   心跳125次/分，呼吸23次/分     1     0  0.340
# 66                  剩餘2顆未服之Midodrine ，已交班請病房護理師明日協助退藥     0     1  0.767
# 67                                表腹痛存，查房醫師表已有常規止痛藥服用     1     0  0.099
# 68                      透析前量完體重有兔胃消化液量約50ml，醫師徐世平囑可透析     0     1  0.998
# 69                                故又開始放血HD，但反覆歷經三次仍如此     0     1  0.963
# 70                         透析前量體重後有嘔吐胃消化液，徐世平醫師診視囑血壓高     0     1  0.986
# 71                       要求提早結束透析，BP91/56mmhg HR75下/分     0     1  0.925
# 72                                     疼痛未改善，要求提早結束透析     0     1  0.512
# 73           血液流速維持200 ml/min，透析中at:1105 BP:82/46mmHg     1     0  0.286
# 74                    至20：25 BP：93/50 mmHg，予提早5分鐘結束透析     0     1  0.732
# 75           休息至21:30表不適改善，perm cath Heparin lock use     1     0  0.361
# 76         經過20分鐘BP仍偏低:72/40mmHg，於13:40Dr.彭囑現直接開始進行透析     0     1  0.812
# 77                        今機器面板顯示脫水200ml，透析中N/S 400ml     1     0  0.163
# 78                                     告知阮筠婷醫師知，囑如有改善     0     1  0.554
# 79               兒表示今血壓偏低及病人較疲倦有胃口不好情形，家中血壓約100mmHg左右     0     1  0.998
# 80                                 抱怨躺不住，協助安撫情緒並採舒適臥位     0     1  0.923
# 81                    AVF thrill(++)，電話告知病房護理師透析中血壓偏高     0     1  0.623
# 82       Fe-back 40mg iv at 1945-2045HD畢，病人表有點頭暈及頭痛情形     1     0  0.489
# 83                       至21：55結束透析抽筋有改善，機器面版顯示脫水3.8L     0     1  1.000
# 84               血液流速維持200ml/min，於:10:10 BP85.54:mmHg     0     1  0.519
# 85          立即趕血並補N/S 0.4L，致電於邱彥霖醫師告知現脫水2.0L以及仍有一小時未洗     1     0  0.366
# 86                          p`t c/o 不適，提早10min ending     1     0  0.026
# 87                         SPO2:96%，  吳泓彥醫師囑予B級運送返回急診     0     1  0.937
# 88                                 病人表示比較好了，想去一樓大廳坐休息     1     0  0.002
# 89  身上管路:NG、perm、左鼠蹊CVP存皆固定可，從病房帶入Levophoed 14mg i...     1     0  0.021
# 90                            30護理師及家屬陪同推床離開HDR至急診就醫，     1     0  0.466
# 91                        血液流速維持200-250ml/min，透析中血壓偏低     1     0  0.424
# 92                                 無 || 其他-病人表示症狀有較改善     0     1  0.994
# 93                         無 || 頭暈-其他,主訴還是有一點頭暈情形，續觀察     1     0  0.120
# 94                                   DR白玫芬囑不再脫水。 || 無     1     0  0.017
# 95  nesp 20mcg iv at 14:41. || 其他-因shake 協助調整BF:18...     1     0  0.190
# 96     病人訴左膝抽筋，蔡萬全醫師診視後建議增加rivotril dose，病人可了解接受 || 無     1     0  0.112
# 97                                    協助服用升壓藥予拔針 || 無     1     0  0.421
# 98  無 || 其他-病人因 EKG short run VT. 15:05 Amiodarone...     1     0  0.121
#
#        資料型態
# 0    PeriHD
# 1    PeriHD
# 2    PeriHD
# 3    PeriHD
# 4    PeriHD
# 5    PeriHD
# 6    PeriHD
# 7    PeriHD
# 8    PeriHD
# 9    PeriHD
# 10   PeriHD
# 11   PeriHD
# 12   PeriHD
# 13   PeriHD
# 14   PeriHD
# 15   PeriHD
# 16   PeriHD
# 17   PeriHD
# 18   PeriHD
# 19   PeriHD
# 20   PeriHD
# 21   PeriHD
# 22   PeriHD
# 23   PeriHD
# 24   PeriHD
# 25   PeriHD
# 26   PeriHD
# 27   PeriHD
# 28   PeriHD
# 29   PeriHD
# 30   PeriHD
# 31   PeriHD
# 32   PeriHD
# 33   PeriHD
# 34   PeriHD
# 35   PeriHD
# 36   PeriHD
# 37   PeriHD
# 38   PeriHD
# 39   PeriHD
# 40   PeriHD
# 41   PeriHD
# 42   PeriHD
# 43   PeriHD
# 44   PeriHD
# 45   PeriHD
# 46   PeriHD
# 47   PeriHD
# 48   PeriHD
# 49   PeriHD
# 50   PeriHD
# 51   PeriHD
# 52   PeriHD
# 53   PeriHD
# 54   PeriHD
# 55   PeriHD
# 56   PeriHD
# 57   PeriHD
# 58   PeriHD
# 59   PeriHD
# 60   PeriHD
# 61   PeriHD
# 62   PeriHD
# 63   PeriHD
# 64   PeriHD
# 65   PeriHD
# 66   PeriHD
# 67   PeriHD
# 68   PeriHD
# 69   PeriHD
# 70   PeriHD
# 71   PeriHD
# 72   PeriHD
# 73   PeriHD
# 74   PeriHD
# 75   PeriHD
# 76   PeriHD
# 77   PeriHD
# 78   PeriHD
# 79   PeriHD
# 80   PeriHD
# 81   PeriHD
# 82   PeriHD
# 83   PeriHD
# 84   PeriHD
# 85   PeriHD
# 86   PeriHD
# 87   PeriHD
# 88   PeriHD
# 89   PeriHD
# 90   PeriHD
# 91   PeriHD
# 92  IntraHD
# 93  IntraHD
# 94  IntraHD
# 95  IntraHD
# 96  IntraHD
# 97  IntraHD
# 98  IntraHD

# %%
temp = {'斷句': [],'真實答案': [],'預測答案': [],'預測分數': [], '資料型態': []}
for i in zip(USD_data_valid['text'].tolist(), USD_data_valid['label'].tolist(),test_binary_pred.flatten(), test_pred.flatten(), USD_data_valid.datatype):
    if i[1]!=i[2]:
        temp['斷句'].append(i[0])
        temp['真實答案'].append(i[1])
        temp['預測答案'].append(i[2])
        temp['預測分數'].append(np.round(i[3],3))
        temp['資料型態'].append(i[4])
test_failed_pf = pd.DataFrame(temp, columns=['斷句','真實答案','預測答案','預測分數', '資料型態'])

# %%
test_failed_pf
# Out:
#                                                    斷句  真實答案  預測答案   預測分數  \
# 0         依血壓調整透析速率，by order LPRBC 2U for Hb 7.9gm/dl     1     0  0.471
# 1                                 徐世平醫師囑ENH HD， 予病房交班     1     0  0.063
# 2        血液流速維持180 ml/min，透析中主訴呼吸喘狀況予on EKG monitor使用     1     0  0.176
# 3              醫師診視後囑休息20分續透析，AT 0940預續透析但病人拒表示心臟還是不適     1     0  0.341
# 4                AVF thrill(++)易姿位性低血壓故通知家屬，疑似透析前體重有誤     0     1  0.774
# 5                    至19：30vomitting 予hold HD，告知徐愷翔醫師     1     0  0.416
# 6                             C/O呼吸不順須坐著透析，at1900訴呼吸喘     1     0  0.045
# 7                        且有vomiting情形，Dr.白囑今脫水4.0Kg即可     1     0  0.009
# 8                        HD中血壓穩定至19：30結束透析，HD畢HF clea     0     1  0.526
# 9   on Dopamin 1.6mg dextrose hydronse 50mg/250ml ...     1     0  0.112
# 10                           預ON Endo ，徐愷翔醫師囑call 999     1     0  0.001
# 11                        於1915 BP 89/48mmHg，給予提早結束透析     0     1  0.744
# 12               預透析3.5小時，透析中血壓不穩定維持在70-131/34-55mmHg     1     0  0.159
# 13                                      at1900訴呼吸喘，不適     1     0  0.003
# 14              Fe-back 40mg iv at10:47-11:47，透析後不適改善     1     0  0.189
# 15            血液流速維持200 ml/min，至17：35因血壓：70~80/40mmHg     1     0  0.107
# 16                        血壓偏高無不適，建議病人返家測量血壓若大於仍需服降壓藥     0     1  0.876
# 17  at11:40 by Dr曾博郁order予提早1小時結束透析，並予Ipratran 1am...     1     0  0.048
# 18                前來探視病人，開立VENA 1 AMP IV ST 囑打完藥後再回病房     1     0  0.001
# 19                         血液流速維持220-250ml/min，透析中血壓低     1     0  0.341
# 20               透析中狀況穩定無特殊不適情形， EASY DOPA IV 10ML/HR     1     0  0.116
# 21              at11:00主訴喘不適、呼吸有whezzing聲，RR：35-40次/分     1     0  0.001
# 22                               RR36次/分，   並請徐世平醫師診視     1     0  0.052
# 23         予N/C O2 3L/min use then SPO2 92%，通知Dr吳泓彥探視     1     0  0.000
# 24                           AVG血管穿刺處已止血，透析後仍偶呻吟全身痛不適     1     0  0.024
# 25                 今共脫水1.5 L，AT19:51意識改變血壓188/112mmHg     1     0  0.005
# 26            AT 0940預續透析但病人拒 表示心臟還是不適，  徐世平醫師囑ENH HD     1     0  0.473
# 27                     予O2N/C 3L/MINUSE，AT 0920主訴心臟不適     1     0  0.425
# 28                                          BP低，無不適情形     1     0  0.212
# 29                 HD中SBP82~145MMHG，at 1955 HD ending     0     1  0.509
# 30                                    仍主訴頭痛無法忍受，告知醫師後     0     1  0.912
# 31                           透析中血壓偏低，血液流速維持200 ml/min     1     0  0.302
# 32                       補水NS800故未脫水，透析後血壓：120/77mmHg     1     0  0.314
# 33             予回血HOLD HD並ON EKG MONITOR，血壓131/71MMHG     1     0  0.362
# 34                         今面板顯示共脫水：0.8公斤，補水NS800故未脫水     1     0  0.003
# 35                 HD 病患只服用midodrine 2# po，至22：00結束透析     0     1  0.940
# 36      血液流速維持150-200ml/min，at11:00主訴喘不適、呼吸有whezzing聲     1     0  0.008
# 37                    EASY DOPA IV 10ML/HR，至17：30結束透析     1     0  0.086
# 38                          AT 0820開始透析，  透析至0905主訴胸悶     1     0  0.437
# 39                                   主訴頭痛未改善，告知邱彥霖醫師後     0     1  0.904
# 40                              楊正雯醫師囑今預透析4小時，脫水2.5 L     0     1  0.654
# 41                透析中by BP set UFR，於1915 BP 89/48mmHg     0     1  0.742
# 42                           EKG Monitor，並告知徐愷翔醫師囑OBS     0     1  0.937
# 43                            Dr.徐世平囑不勉強脫水，至11：28結束透析     0     1  0.836
# 44                                 要求提早收針，予以提早十分鐘結束透析     0     1  0.790
# 45                                徐世平醫師囑ENH HD， 予病房交班     1     0  0.063
# 46  Fe-back 40mg IV since 19：40 to 20：40 by order ...     1     0  0.012
# 47                     因躺不住要求提前25分鐘結束透析，今機器面版顯示脫水2.1L     0     1  0.574
# 48                                  RR36次/分，並請徐世平醫師診視     1     0  0.071
# 49     徐愷翔醫師囑call 999，於19:55協助 on endo 7.0號fix 24 cm      1     0  0.130
# 50           予回血HOLD HD並ON EKG MONITOR，  血壓131/71MMHG     1     0  0.360
# 51                                  今預透析3.5小時，透析中血壓穩定     0     1  0.720
# 52                                     告知徐愷翔醫師，前來探視病人     1     0  0.340
# 53            Dr吳表SPO2 90%以上就可透析故於18：35開始進行透析，今預透析2小時     0     1  0.758
# 54                         Dr.白囑可提早結束，透析後血壓150/71mmHg     1     0  0.498
# 55  透析中主訴呼吸喘狀況予on EKG monitor使用，抽血Ca:5.4mg/dl依醫囑給藥...     1     0  0.265
# 56                  AT19:51意識改變血壓188/112mmHg，SPO2:74%     1     0  0.292
# 57  開立VENA 1 AMP IV ST 囑打完藥後再回病房，AT 19:40血壓211/78m...     1     0  0.011
# 58                                    不適，且有vomiting情形     1     0  0.000
# 59                   主訴無胸悶或其他不適，協助O2 3L/min鼻導管使用 || 無     0     1  0.900
# 60                               Shake，N/S flash || 無     1     0  0.098
# 61                                 病人主訴腳痛已有改善，續觀 || 無     0     1  0.640
# 62             無 || 胸口不適 /-監測生命徵象,給氧,其他,O2 3L/min use     1     0  0.176
# 63             無 || 其他-Midodrine 2# po.Rivotril 1# po     0     1  0.987
# 64                          病人主訴無不適，要求休息10分鐘暫不脫水 || 無     0     1  0.999
# 65           無 || 其他-病患持續吐告知蔡萬全醫師by order give HD end     1     0  0.085
# 66                  無 || 其他-Heart不好，曾博郁醫師查房表調整BF:250。     0     1  0.543
# 67                                          無 || 抽筋-;     1     0  0.366
# 68  協助趕血並通知Dr.潘思宇 || 其他-主訴又開始呼吸困難，O2 5L/min鼻導管使用SP...     1     0  0.004
# 69  NESP 20mcg iv at19:30 || 其他-病人表示腳痠不適，予調整BF:180...     1     0  0.345
#
#        資料型態
# 0    PeriHD
# 1    PeriHD
# 2    PeriHD
# 3    PeriHD
# 4    PeriHD
# 5    PeriHD
# 6    PeriHD
# 7    PeriHD
# 8    PeriHD
# 9    PeriHD
# 10   PeriHD
# 11   PeriHD
# 12   PeriHD
# 13   PeriHD
# 14   PeriHD
# 15   PeriHD
# 16   PeriHD
# 17   PeriHD
# 18   PeriHD
# 19   PeriHD
# 20   PeriHD
# 21   PeriHD
# 22   PeriHD
# 23   PeriHD
# 24   PeriHD
# 25   PeriHD
# 26   PeriHD
# 27   PeriHD
# 28   PeriHD
# 29   PeriHD
# 30   PeriHD
# 31   PeriHD
# 32   PeriHD
# 33   PeriHD
# 34   PeriHD
# 35   PeriHD
# 36   PeriHD
# 37   PeriHD
# 38   PeriHD
# 39   PeriHD
# 40   PeriHD
# 41   PeriHD
# 42   PeriHD
# 43   PeriHD
# 44   PeriHD
# 45   PeriHD
# 46   PeriHD
# 47   PeriHD
# 48   PeriHD
# 49   PeriHD
# 50   PeriHD
# 51   PeriHD
# 52   PeriHD
# 53   PeriHD
# 54   PeriHD
# 55   PeriHD
# 56   PeriHD
# 57   PeriHD
# 58   PeriHD
# 59  IntraHD
# 60  IntraHD
# 61  IntraHD
# 62  IntraHD
# 63  IntraHD
# 64  IntraHD
# 65  IntraHD
# 66  IntraHD
# 67  IntraHD
# 68  IntraHD
# 69  IntraHD

# %%
pd.concat([train_failed_pf, test_failed_pf]).to_csv("./failed_predict_peri+intra_sentence_train&test[merge-neg+pos].csv", encoding='utf-8-sig', index=False)

# %%
mark_train
# Out:
#       USD Metric Train  fold-1  fold-2  fold-3  fold-4  fold-5    Mean     Std
# 0             Accuracy  0.9887  0.9922  0.9896  0.9903  0.9924  0.9906  0.0015
# 1    Precision [macro]  0.9778  0.9814  0.9793  0.9819  0.9856  0.9812  0.0026
# 2  Sensitivity [macro]  0.9669  0.9808  0.9700  0.9707  0.9776  0.9732  0.0052
# 3          Specificity  0.9953  0.9957  0.9956  0.9963  0.9970  0.9960  0.0006
# 4     F1-score [macro]  0.9723  0.9811  0.9746  0.9762  0.9815  0.9771  0.0036

# %%
mark_test
# Out:
#        USD Metric Test  fold-1  fold-2  fold-3  fold-4  fold-5    Mean     Std
# 0             Accuracy  0.9502  0.9538  0.9562  0.9508  0.9580  0.9538  0.0030
# 1    Precision [macro]  0.9226  0.9230  0.9287  0.9181  0.9305  0.9246  0.0045
# 2  Sensitivity [macro]  0.8561  0.8731  0.8782  0.8639  0.8848  0.8712  0.0102
# 3          Specificity  0.9854  0.9840  0.9854  0.9833  0.9854  0.9847  0.0009
# 4     F1-score [macro]  0.8853  0.8957  0.9012  0.8883  0.9058  0.8953  0.0077
